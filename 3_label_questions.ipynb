# %% [markdown]
# # Load dataset

# %%
# Upload 'parsed_questions_benepar.csv' to run
import pandas as pd

parsed_questions = pd.read_csv('parsed_questions_benepar.csv')
parsed_questions
# Out:
#          Contestant                                           Question  \
# 0        Aaron Gold  According to Good Housekeeping, most homeowner...
# 1        Aaron Gold  "There is a Sucker Born Ev'ry Minute" and "Joi...
# 2        Aaron Gold  Until it adopted the euro in 2002, fittingly, ...
# 3        Aaron Gold  Which of these is the correct spelling of what...
# 4       Aaron Hauck  In 2006, the WHO reported that thousands of pe...
# ...             ...                                                ...
# 24790  Zeke Spector  As Crayola's website explains, "while artists ...
# 24791  Zeke Spector  Born Amethyst Amelia Kelly, what recording art...
# 24792  Zeke Spector  Which one of these things is NOT true of the p...
# 24793  Zeke Spector  Since in 1992 it was ruled that anyone in the ...
# 24794  Zeke Spector  In photographs, Harriet Tubman is often seen w...
#
#                                                    Parse
# 0      (S (PP (VBG According) (PP (IN to) (NP (NNP Go...
# 1      (S (NP (`` ") (S (NP (EX There)) (VP (VBZ is) ...
# 2      (SBARQ (SBAR (IN Until) (S (NP (PRP it)) (VP (...
# 3      (SBARQ (WHNP (WHNP (WDT Which)) (PP (IN of) (N...
# 4      (S (PP (IN In) (NP (CD 2006))) (, ,) (NP (DT t...
# ...                                                  ...
# 24790  (S (SBAR (IN As) (S (NP (NP (NNP Crayola) (POS...
# 24791  (SBARQ (S (VP (VBN Born) (NP (NNP Amethyst) (N...
# 24792  (SBARQ (WHNP (NP (WDT Which) (CD one)) (PP (IN...
# 24793  (S (SBAR (IN Since) (S (PP (IN in) (NP (CD 199...
# 24794  (S (PP (IN In) (NP (NNS photographs))) (, ,) (...
#
# [24795 rows x 3 columns]

# %%
# Take the parse strings from the csv file and turn them into nltk tree objects
from nltk.tree import *

trees = [Tree.fromstring(tree) for tree in parsed_questions['Parse'].tolist()]

# %%
# Take a look at a particular tree
trees[415].pretty_print()
# Out:
#                              SBARQ
#   _____________________________|____________________________________
#  |                             SQ                                   |
#  |     ________________________|________                            |
#  |    |    |                            VP                          |
#  |    |    |        ____________________|_______                    |
#  |    |    |       |           |                S                   |
#  |    |    |       |           |                |                   |
#  |    |    |       |           |                VP                  |
#  |    |    |       |           |             ___|____               |
#  |    |    |       |           PP           |        VP             |
#  |    |    |       |      _____|____        |    ____|______        |
# WHNP  |    NP      |     |          NP      |   |           NP      |
#  |    |    |       |     |      ____|___    |   |           |       |
#  WP  VBP  NNS      VB    IN    DT       NN  TO  VB          NN      .
#  |    |    |       |     |     |        |   |   |           |       |
# What  do planes release into  the      air  to form     skywriting  ?

# %% [markdown]
# # Basic relations

# %%
def dominates(pos1, pos2):
    len1, len2 = len(pos1), len(pos2)
    if len2 > len1 and pos2[:len1] == pos1:
        return True
    else:
        return False

def ccommands(pos1, pos2):
    len1, len2 = len(pos1), len(pos2)
    strictness = False if len1==len2 else True
    if pos1!=pos2 and not dominates(pos1,pos2) and len2 >= len1 and pos2[:len1-1] == pos1[:len1-1] and strictness:
        return True
    else:
        return False

def is_higher_than(pos1, pos2):
    return dominates(pos1, pos2) or ccommands(pos1, pos2)

def get_ancestors(tree, pos):
    ancestors = [pos[:i-1] for i in range(len(pos))]
    return ancestors

def get_descendants(tree, pos):
    positions = [position for position in tree.treepositions() if isinstance(tree[position], Tree)]
    descendants = [position for position in positions if len(position) > len(pos) and position[:len(pos)]==pos]
    return descendants

def get_mother(tree, pos):
    mother = pos[:len(pos)-1]
    return mother

def get_siblings(tree, pos):
    positions = [position for position in tree.treepositions() if isinstance(tree[position], Tree)]
    siblings = [position for position in positions if len(position)==len(pos) and get_mother(tree,position)==get_mother(tree,pos) and position!=pos]
    return siblings

def get_daughters(tree, pos):
    positions = [position for position in tree.treepositions() if isinstance(tree[position], Tree)]
    daughters = [position for position in positions if len(position) == len(pos)+1 and position[:len(pos)]==pos]
    return daughters

# %%
# We will illustrate these relations with a test tree
tree = trees[76]
tree.pretty_print()
# Out:
#                           SBARQ
#             ________________|________________________
#           WHNP                        SQ             |
#    ________|_____                     |              |
#   |              PP                   VP             |
#   |     _________|____             ___|___           |
#  WHNP  |              NP          |       NP         |
#   |    |          ____|_____      |    ___|____      |
#  WDT   IN        DT        NNS   VBZ  DT       JJ    .
#   |    |         |          |     |   |        |     |
# Which  of      these     animals  is  a      simian  ?

# %%
# Illustrating the 'dominates' relation
PP = (0,1)
for pos in tree.treepositions():
    if dominates(PP, pos) and isinstance(tree[pos], Tree):
        tree[pos].pretty_print()
# Out:
#  IN
#  |
#  of
#
#        NP
#    ____|_____
#   DT        NNS
#   |          |
# these     animals
#
#   DT
#   |
# these
#
#   NNS
#    |
# animals

# %%
# Illustrating the 'ccommand' relation
WHNP = (0,)
for pos in tree.treepositions():
    if ccommands(WHNP, pos) and isinstance(tree[pos], Tree):
        tree[pos].pretty_print()
# Out:
#      VP
#   ___|___
#  |       NP
#  |    ___|____
# VBZ  DT       JJ
#  |   |        |
#  is  a      simian
#
# VBZ
#  |
#  is
#
#      NP
#   ___|____
#  DT       JJ
#  |        |
#  a      simian
#
#  DT
#  |
#  a
#
#   JJ
#   |
# simian

# %%
# Illustrating the 'is_higher_than' relation
PP = (0,1)
for pos in tree.treepositions():
    if is_higher_than(PP, pos) and isinstance(tree[pos], Tree):
        tree[pos].pretty_print()
# Out:
#  WDT
#   |
# Which
#
#  IN
#  |
#  of
#
#        NP
#    ____|_____
#   DT        NNS
#   |          |
# these     animals
#
#   DT
#   |
# these
#
#   NNS
#    |
# animals

# %% [markdown]
# # Relabel fronted Ss

# %%
def preposed_S(tree, pos):
    '''
    A preposed S node has the following properties:
    1. Followed by a comma
    2. First daughter is a VP, OR first daughter is a preposition
    '''
    if tree[pos].label().startswith('S'):
        if len(pos)>0:
            siblings = get_siblings(tree, pos)
            my_idx = pos[-1]
            if len(siblings) > my_idx+1:
                my_right_sib = pos[:-1] + (my_idx+1,)
                if tree[my_right_sib].label() == ',':
                    daughters = get_daughters(tree, pos)
                    if tree[daughters[0]].label().startswith('VP'):
                        return True
                    elif tree[daughters[0]].label() == 'IN':
                        return True
    return False

# %%
# Preposed Ss cause problems with the definitions below (particularly identifying main S node).
# In order to get around this, we will change relevant S categories to SPP.
from tqdm import tqdm

for i,tree in tqdm(list(enumerate(trees))):
    positions = [position for position in tree.treepositions() if isinstance(tree[position], Tree)]
    for position in positions:
        if preposed_S(tree, position):
            tree[position].set_label('SPP')
# Out:
# 100%|██████████| 24795/24795 [00:21<00:00, 1144.44it/s]

# %%
# Looking at a representative example
trees[21991].pretty_print()
# Out:
#                                                                                SBARQ
#                    ______________________________________________________________|__________________________________________________________________
#                   |                              |               |                    VP                                                            |
#                   |                              |               |                ____|_________                                                    |
#                   |                              |               |               |    |         NP                                                  |
#                   |                              |               |               |    |     ____|___________                                        |
#                  SPP                             |               |               |    |    |                PP                                      |
#                   |                              |               |               |    |    |     ___________|________                               |
#                   VP                             |               |               |    |    |    |                    NP                             |
#    _______________|__________                    |               |               |    |    |    |        ____________|____                          |
#   |                          VP                  |               |               |    |    |    |       |                 PP                        |
#   |        __________________|_________          |               |               |    |    |    |       |         ________|____                     |
#   |       |            |               PP        |              WHNP             |    |    |    |       |        |             NP                   |
#   |       |            |            ___|____     |          _____|_________      |    |    |    |       |        |         ____|_____________       |
#   |       |            NP          |        NP   |        WHNP        |    |     |   ADVP  NP   |       NP       |        NP         |       |      |
#   |       |        ____|_____      |        |    |    _____|_____     |    |     |    |    |    |    ___|___     |    ____|____      |       |      |
#  VBG     VBN      JJ        NNS    IN       NN   ,  WDT    NN   POS   JJ   NN   VBZ   RB   NN   IN  DT      NN   IN  DT   NN  POS   JJS      NN     .
#   |       |       |          |     |        |    |   |     |     |    |    |     |    |    |    |   |       |    |   |    |    |     |       |      |
# Having achieved great     heights  in     music  ,  what rapper  's  last name   is  also part  of the     name  of the world  's tallest building  ?

# %% [markdown]
# # Identify main clause constituents

# %%
def bounding_node(tree, pos):
    '''
    Take a tree,node pair and determine whether the node is a bounding node.
    Bounding nodes have the following properties:
    1. The node is of category S, NP, or PP,
    2. The node and its mother are of different categories.
    '''
    if len(pos)>0:
        start_S = lambda p: tree[p].label().startswith('S')
        if start_S(pos) and not start_S(get_mother(tree,pos)):
            return True
        end_NPP = lambda p: tree[p].label().endswith('PP') or tree[p].label().endswith('NP')
        if end_NPP(pos) and not end_NPP(get_mother(tree,pos)):
            return True
    return False

def get_main_clause(tree):
    '''
    The main clause consists of all nodes dominated by zero bounding nodes.
    '''
    positions = [position for position in tree.treepositions() if isinstance(tree[position], Tree)]

    out = []
    for position in positions:
        ancestors = get_ancestors(tree, position)
        if not any(bounding_node(tree,ancestor) for ancestor in ancestors):
            out.append(position)

    return out

# %%
# Illustrating 'get_main_clause'
tree = trees[76]
main_clause = get_main_clause(tree)
for pos in main_clause:
    tree[pos].pretty_print()
# Out:
#                           SBARQ
#             ________________|________________________
#           WHNP                        SQ             |
#    ________|_____                     |              |
#   |              PP                   VP             |
#   |     _________|____             ___|___           |
#  WHNP  |              NP          |       NP         |
#   |    |          ____|_____      |    ___|____      |
#  WDT   IN        DT        NNS   VBZ  DT       JJ    .
#   |    |         |          |     |   |        |     |
# Which  of      these     animals  is  a      simian  ?
#
#           WHNP
#    ________|_____
#   |              PP
#   |     _________|____
#  WHNP  |              NP
#   |    |          ____|_____
#  WDT   IN        DT        NNS
#   |    |         |          |
# Which  of      these     animals
#
#      SQ
#      |
#      VP
#   ___|___
#  |       NP
#  |    ___|____
# VBZ  DT       JJ
#  |   |        |
#  is  a      simian
#
#      VP
#   ___|___
#  |       NP
#  |    ___|____
# VBZ  DT       JJ
#  |   |        |
#  is  a      simian
#
# VBZ
#  |
#  is
#
#      NP
#   ___|____
#  DT       JJ
#  |        |
#  a      simian
#
#  .
#  |
#  ?

# %%
def get_maximal(tree, cats, exact='prefix'):
    '''
    A node of a given category is "maximal" if it is neither dominated by or c-commanded by another node of the given category within the main clause
    In this function, we can look for exact matches, prefixal matches, or suffixal matches
    '''
    if isinstance(cats, str):
        cats = [cats]
    main_clause = get_main_clause(tree)
    # Here we handle possible prefix matching.
    if exact=='exact': # With an "exact match" requirement, just check whether the exact label appears in the specified cats list
        candidates = [position for position in main_clause if tree[position].label() in cats]
    elif exact=='prefix': # Otherwise, check whether any specified cat is a prefix of the exact label
        candidates = [position for position in main_clause if any(tree[position].label().startswith(cat) for cat in cats)]
    elif exact=='suffix':
        candidates = [position for position in main_clause if any(tree[position].label().endswith(cat) for cat in cats)]
    # Return
    return [candidate for candidate in candidates if not any(is_higher_than(competitor, candidate) for competitor in candidates)]

# %%
# Illustrating 'get_maximal'
tree = trees[76]
max_NPs = get_maximal(tree, 'NP', exact='suffix')
for max_NP in max_NPs:
    tree[max_NP].pretty_print()
# Out:
#           WHNP
#    ________|_____
#   |              PP
#   |     _________|____
#  WHNP  |              NP
#   |    |          ____|_____
#  WDT   IN        DT        NNS
#   |    |         |          |
# Which  of      these     animals

# %% [markdown]
# # Main S node

# %%
def get_main_S(tree):
    '''
    The main S node has the following properties:
    1. It is not dominated by anything other than S nodes,
    2. It dominates all maximal NPs and VPs,
    3. None of its descendants dominate all maximal NPs and VPs (i.e. the lowest such node).
    '''

    main_clause = get_main_clause(tree)

    # 1. Get S nodes dominated by nothing but other S nodes
    S_segments = []
    for position in main_clause:
        if tree[position].label().startswith('S'):
            ancestors = get_ancestors(tree, position)
            if (len(ancestors)==0) or all(tree[ancestor].label().startswith('S') for ancestor in ancestors):
                S_segments.append(position)
    # Bail if failed
    if len(S_segments)==0:
        return None

    # 2. Narrow down to only S segments that dominate all the maximal NPs and VPs
    max_NPs = get_maximal(tree, 'NP', exact='suffix')
    max_VPs = get_maximal(tree, 'VP', exact='prefix')
    dominant_Ss = []
    for S_segment in S_segments:
        descendants = get_descendants(tree, S_segment)
        if all(max_NP in descendants for max_NP in max_NPs) and all(max_VP in descendants for max_VP in max_VPs):
            dominant_Ss.append(S_segment)
    # Bail if failed
    if len(dominant_Ss)==0:
        return None

    # 3. Narrow down to the minimal such S node
    return max(dominant_Ss, key=lambda x: len(x)) # Use max here to get the longest index (i.e. lowest node)

# %%
# Illustrating 'get_main_S'
# Note that the 'main S' node may not be the root...
tree = trees[21572]
tree.pretty_print()
main_S = get_main_S(tree)
tree[main_S].pretty_print()
# Out:
#                      SBARQ
#    ____________________|_______________________
#   |                    SQ                      |
#   |      ______________|__________________     |
#   |     |              NP                 |    |
#   |     |    __________|_____________     |    |
# WHADVP  |   |    |         NML       |    VP   |
#   |     |   |    |      ____|___     |    |    |
#  WRB   VBD  DT   JJ   NNP      NNP  NNP   VB   .
#   |     |   |    |     |        |    |    |    |
# Where  did the first  Hard     Rock Cafe open  ?
#
#                SQ
#   _____________|__________________
#  |             NP                 |
#  |    _________|_____________     |
#  |   |    |        NML       |    VP
#  |   |    |     ____|___     |    |
# VBD  DT   JJ  NNP      NNP  NNP   VB
#  |   |    |    |        |    |    |
# did the first Hard     Rock Cafe open

# %%
# Checking bail rate
fails = [i for i,tree in tqdm(list(enumerate(trees))) if get_main_S(tree) is None]
passes = [j for j in range(len(trees)) if j not in fails]
print('Passes:', len(passes))
print('Fails:', len(fails))
print('Total:', len(trees))
# Out:
# 100%|██████████| 24795/24795 [01:04<00:00, 386.35it/s]
# Passes: 24519
# Fails: 276
# Total: 24795

# %%
# Check handling of edge cases
# Specifically, cases wehre the main S is not the root node
edge_cases = [i for i in tqdm(passes) if trees[i][get_main_S(trees[i])] != trees[i]]
print('\n', len(edge_cases))
# Out:
# 100%|██████████| 24519/24519 [01:03<00:00, 383.83it/s]
#  749

# %%
# If we want, we can look at the sentences
for i in edge_cases:
    print(i, parsed_questions['Question'][i])
# Out:
# 17 If philosophers hosted daytime TV, on what show might you hear, "It is not a lack of love, but a lack of friendship that makes unhappy marriages?
# 70 On which classic sitcom were the actors who played the main family's "mom" and "dad" born on the exact same day: June 21, 1947?
# 143 Where will the Summer Olympic Games be held in the year 2000?
# 169 Where would a person go to put something into hock?
# 206 At which of these ages might a person typically have a midlife crisis?
# 216 In what children's game does a player call out, "Ready or not, here I come"?
# 260 Where would you find the “crypts of Lieberkühn”?
# 291 On what piece of household furniture would one be most likely to find a duvet?
# 294 In which country does most of the action in the movie "Casablanca" take place?
# 308 For what NBA team did former presidential candidate Bill Bradley play?
# 439 In what activity do people use siteswap notation to keep track of the many complex patterns?
# 497 Based on the lunar calendar, in which country is the Tet holiday celebrated not only as New Year's but traditionally also as everyone's birthday?
# 557 In the children's book "The Little Prince," where is the title character's home?
# 574 During one of his presidential campaigns, whose group of close advisers was called the "Brain Trust"?
# 605 On what part of your body would you normally apply a "defrizzer"?
# 611 On what island was Napoleon I born?
# 629 According to the popular saying, how is the grass always different "on the other side of the fence"?
# 635 By what name did former New York City postal worker David Berkowitz become known?
# 683 To which of the following people would you go if you needed a haircut?
# 697 In what subject do students learn "The Five Ws"?
# 702 Where is the famous Prado museum?
# 2139 In what 1980s movie was a character's refrigerator shown to contain Coke, Perrier and Zuul the terror dog?
# 2176 In what year did Christopher Columbus discover America?
# 2180 At which of the following times would a nocturnal animal most likely sleep?
# 2240 In what shape are the bowling pins organized in a traditional game of bowling?
# 2249 According to the children’s book, why is Dr. Dolittle able to talk to the animals?
# 2319 If you need a synonym for a word, where is the best place to look?
# 2373 In what year did man first walk on the moon?
# 2512 In the film "Notting Hill", where does Hugh Grant's character work?
# 2523 Where is the commemorative statue of the film character Rocky Balboa?
# 2561 In what movie does a character quiz his fiancée on the Baltimore Colts before agreeing to marry her?
# 2580 In which of these places would a teller most likely work?
# 2599 By definition, where would you most likely find an epicanthic fold?
# 2600 In which state would you find the northernmost border in the contiguous United States?
# 2610 If you wanted to visit Tierra del Fuego, to which continent would you travel?
# 2639 Where did Robert E. Lee surrender to Ulysses S. Grant, effectively ending the U.S. Civil War?
# 2710 According to the Old Testament, how long did it rain when Noah and the animals were on the ark?
# 2711 In what aspect of moviemaking was the Max Factor company considered innovative?
# 2731 In the song, "I've Been Working on the Railroad," how long has the singer been working on the railroad?
# 2742 In what sport are athletes judged on their approach, takeoff, flight, execution and entry into the water?
# 2771 In which of the following places would you most likely keep a pet piranha?
# 2855 If you are driving in the "Motor City," where are you?
# 2928 Where are the Knockmealdown Mountains?
# 3004 In what U.S. state would you find the Biosphere 2 facility?
# 3036 On what holiday do American children customarily go “trick or treating”?
# 3046 In what city did talk show host Oprah Winfrey get her first job in television?
# 3110 Where would you most likely find a "blurb"?
# 3113 Where do manned U.S. space shuttle launches take place?
# 3212 In which of these films does Whoopi Goldberg dress up as a nun?
# 3219 How was Joan of Arc executed?
# 3279 In the U.S., where on the body is an engagement ring traditionally worn?
# 3298 How do you typically turn a jalapeño pepper into a chipotle pepper?
# 3309 In what city does the action in the musical "Cabaret" take place?
# 3387 In what Broadway musical does a chorus of teens sing, "Tell me more, tell me more, did you get very far"?
# 3456 In which of these sports do players hit the ball with topspin?
# 3472 On what day of the week is the federal holiday known as Memorial Day observed?
# 3490 In the Billy Joel song "Piano Man," when does "the regular crowd" shuffle in?
# 3492 During what season do some countries experience a phenomenon known as the "midnight sun"?
# 3567 In which of these sports are most players not allowed to use their hands?
# 3576 In what country did the dance known as the rumba originate?
# 3610 In what 1979 hit single does the singer claim, "Yes, I like pina coladas"?
# 3641 On what TV series does a character spout sayings known as "fishisms"?
# 3645 In which of the following places would an avalanche most likely occur?
# 3647 In what sport do resting players sit in a dugout?
# 3658 Where should choking victims place their hands to indicate to others that they need help?
# 3660 In what "language" would you say "ello-hay" to greet your friends?
# 3665 In what U.S. town did the famous 1881 shoot-out at the O.K. Corral take place?
# 3675 Where is the stinger on a scorpion's body?
# 3683 Where was Russian revolutionary leader Leon Trotsky murdered in 1940?
# 3688 In the fairy tale "The Princess and the Pea", where was the pea placed to keep the princess from sleeping?
# 3689 Where was the one weak spot of the legendary Greek warrior Achilles?
# 3869 In which of these romantic comedies do the two main characters not meet until the final scene of the film?
# 3925 In which of the following places would you most likely find the condiment holder called a "Lazy Susan"?
# 3948 In which state is the Erie Canal located?
# 3983 On the TV series "Will & Grace," how did Will and Grace first get to know each other?
# 3989 In the "twilight" of his tween years, whose sisters would dress him up as a girl and tell strangers "her" name was Claudia?
# 4167 If you found yourself in the state capital of Kentucky, where would you be?
# 4229 According to the classic TV jingle, how does "America spell cheese"?
# 4231 Where would you be most likely to find a cabana?
# 4278 In which of the following competition movies does the protagonist actually win the big event?
# 4314 In which of these famous tunes does the singer purposefully stutter the first syllable of the song title?
# 4320 Where would you normally find a control tower?
# 4324 In what county would you find the county of Tipperary?
# 4404 Where on the body does one get a sty?
# 4514 Where would you find “mud flaps” on a truck?
# 4537 Aboard what research ship did explorer Jacques Cousteau conduct the majority of his studies?
# 4574 Where would one find the "white meat" on a cooked chicken?
# 4576 Within the human body, where are the hamstrings found?
# 4584 If you “riding shotgun” in a car, where are you sitting?
# 4587 In the 2000 movie “Erin Brockovich,” where does Julia Roberts’ character work?
# 4615 When playing “5-Second Summaries” on “The Tonight Show” recently. Andy Samberg shouted, “I’m in the Cheerios!” as a one-line clue for what film?
# 4689 For which of the following crafts would you use a kiln?
# 4693 In what country is the holy city of Mecca located?
# 4722 Where would you most likely find a neon tetra?
# 4794 On what TV show would you find the character Fox Mulder?
# 4846 Where is the so-called "nosebleed" section of a stadium?
# 4848 Where on the body is it appropriate to wear Doc Martens?
# 4857 According to Bloomberg.com, in what country do adult diapers outsell baby diapers, thanks to 23% of its population being over the age of 65?
# 4907 In what TV series was the main character a 16-year-old doctor?
# 4908 Where is the nape of the neck?
# 4994 In what year did America celebrate the sesquicentennial anniversary of the signing of the Declaration of Independence?
# 5010 In what college town was the satirical newspaper "The Onion" founded in 1988?
# 5025 During the finale of what sitcom series did the cast embrace, singing "It's a long way to Tipperary"?
# 5060 For what crime was gangster Al Capone sentenced to 11 years in prison?
# 5105 Where did author Henry David Thoreau spend two years in a hut in search of a simpler life?
# 5117 If someone shouted "Hey, nice jabot!" when Supreme Court Justice Ruth Bader Ginsburg walked by, they would be complimenting her what?
# 5133 According to a well-known phrase, where shouldn't you put all your eggs?
# 5138 According to the "Guinness Book of Records", where can you find the tallest tree currently standing?
# 5184 According to the popular song, where would you find the "99 Bottles of Beer"?
# 5202 For which of the following activities do fitness trainers normally recommend a "spotter"?
# 5203 How is a standard English dictionary organized?
# 5234 Regarding the first four letters of its name, why is the popular arcade game called Skee-Ball?
# 5277 In what state is The Citadel military college located?
# 5314 Cutting which of the following foods is most likely to cause a person's eyes to tear?
# 5364 In the 1998 film "Shakespeare in Love," at what theatre does the play "Romeo and Juliet" premiere?
# 5488 In what language do women’s last names traditionally end with the letter “a”?
# 5507 According to etiquette, where should you place your napkin after you sit down at the dinner table?
# 5544 In which of the following places would you most commonly find a sauna?
# 5546 On what classic toy can you twist knobs to create lines and drawings?
# 5547 In which of the following places would you most likely find a duty-free shop?
# 5577 On what day of the week would it be most approiate to say "TGIF"?
# 7146 In which of these games do players draw pieces from a pile known as the “boneyard”?
# 7247 According to a common phrase, whose advocate are you playing if you argue a position that you do not necessarily agree with?
# 7338 In what part of the human body are nephrons located?
# 7386 At what southern tourist spot can you check out airplanes named "Lisa Marie" and "Hound Dog II"?
# 7398 In which U.S. city would you currently find the most hotel rooms?
# 7399 Where does lanolin come from?
# 7418 In the United States, in what month are shadows the shortest?
# 7423 Where is the cornea found?
# 7455 In what field did entertainer Bill Cosby earn his doctorate from the University of Massachusetts?
# 7476 From what country did the U.S. purchase Alaska?
# 7561 In which of the following sciences would you most likely study plate tectonics?
# 7619 In which of these movies does Billy Crystal spend a considerable amount of screen time riding a horse?
# 7730 While it sounds like the seat in a port-a-potty, where would you most likely find a place to sit called a pew?
# 7764 On what TV game show do contestants often have to decide whether to spin or solve?
# 7847 According to the lyrics in the first music video shown on MTV, what "killed the radio star"?
# 7915 Where were the Dead Sea Scrolls discovered?
# 7937 Where to the members of the Electoral College usually go to cast their votes?
# 7938 In what U.S. state was General George Custer's "last stand"?
# 7945 During what inning of a baseball game is it tradition for the spectators to stand and stretch?
# 7950 From where did the Dalai Lama flee in 1959?
# 7956 At which of these ages is a person most likely to be called a "tween"?
# 7982 In what state will you find Toad Suck, selected by a 2012 online poll as the "most unfortunate" town name in the country?
# 8025 How should a person throw a rock so that it will "skip" on a lake?
# 8112 Where are the headquarters of London’s police department located?
# 8114 Since Halley’s Comet was last visible from Earth in 1986, when is it expected to return?
# 8222 Where would a poop deck most likely be found?
# 8225 How is a casserole traditionally cooked?
# 8283 In what country does the Loch Ness monster allegedly reside?
# 8292 In what TV series did actor Tom Hanks regularly appear in drag?
# 8318 In which of the following places would you most likely find a docent at work?
# 8370 Where is the palate located in the human body?
# 8479 According to the nursery rhyme, where did Jack and Jill go to fetch a pail of water?
# 8490 According to the popular expression, where should you never look a gift horse?
# 8498 In what city does the first series of MTV's "The Real World" take place?
# 8565 Where on the body would you find the jowls?
# 8569 In what city does the television drama "Homicide: Life on the Street" take place?
# 8576 In the children's book series, where is Paddington Bear originally from?
# 8588 Though he sounds like a Hall of Fame baseball player, who led Suriname when it gained independence from the Netherlands in 1975?
# 8608 Approximately how often does Old Faithful erupt at Yellowstone National Park?
# 8628 At which of these U.S. attractions do visitors often get their picture taken with employees posing as Mickey and Minnie Mouse?
# 8661 How did an ‘90s advertising campaign by Hefty describe the trash bags of their competitors?
# 8664 In what country did the sleeping mat known as a futon originate?
# 8741 Where would you normally go in order to get "French tips"?
# 8764 In which of these sports can players make a mistake called a "foot fault"?
# 8784 In what level of the Earth's atmosphere do commercial airplanes normally travel?
# 8815 Because the book's victim is slain by his servant, for which of the following novels is it most appropriate to say "The butler did it"?
# 8934 In 2011, whose self-portrait sold at Christie's for nearly $3.9 million, reportedly the most ever paid for a photograph at an auction?
# 8968 In a case of art imitating life, whose first novel, "A Time to Run," featured as its heroine a Democratic senator from California?
# 9009 During what part of the day does a person experience the dawn?
# 9012 In what Olympic event would a competitor attempt a "Hamill camel"?
# 9039 In the "Peanuts" comic strip, where did Charlie Brown get Snoopy?
# 9074 To whom is singer Barbra Streisand currently married?
# 9110 In what medieval game does a mounted knight try to knock down a rival with a lance?
# 9111 Where would a man normally wear a boutonniere?
# 9115 In what professional sport has Shirley Muldowney won a national championship?
# 9174 Where do the events depicted in Paul Bowles' novel "The Sheltering Sky" take place?
# 9201 How is the "S.O.S." distress call expressed in Morse code?
# 9247 Where is the Oort cloud?
# 9300 On what television game show are members of the audience encouraged to "come on down"?
# 9303 In what U.S. city would you find the building known as the Space Needle?
# 9317 On a standard U.S. touch-tone telephone, on what number key does the letter D appear?
# 9411 Why does milk appear white?
# 9496 In what decorative art would paper cutouts be pasted onto something, then coated with varnish?
# 9524 Better known as the musical duo the Carpenters, how were Karen and Richard Carpenter related?
# 9532 In what sport would you find a person dressed as a clown who protects the participants?
# 9580 How does Encyclopedia Britannica describe the first woman to be named Time Magazine’s Person of the Year, in 1936?
# 9585 With what part of your body do you give someone a "butterfly" kiss?
# 9615 Where would an aviator be most likely to work?
# 9647 Where would you find the United States Air Force Academy?
# 9648 In which author's works would you find the characters Flopsy, Mopsy and Cottontail?
# 9671 How did comic strip character Dick Tracy earn his living?
# 9786 With what phrase do you traditionally wish an actor "good luck"?
# 9818 Perhaps to the chagrin of his female fans, in which of these movies does Brad Pitt not bare his backside?
# 9841 In what sport might you encounter a wicketkeeper defending wooden stumps?
# 9849 In which type of restaurant would you most likely find food prepared with soy sauce?
# 9850 In what U.S. state is ice cream maker Ben & Jerry's based?
# 9870 On which of the following would you most likely find the initials "R.S.V.P."?
# 9875 By what name does blues legend B.B. King call his Gibson guitar?
# 9934 For which of the following rock groups was Boy George the lead singer?
# 9945 In which of these languages is the first-person singular subject pronoun always capitalized?
# 9979 When does a person most commonly receive severance pay?
# 10064 In what museum would you find Archie Bunker's armchair from the TV show "All in the Family"?
# 10146 Where is the heel located on the human foot?
# 10252 Where is the date entered on a standard bank check?
# 10323 According to the title of a 1980 movie, where was Brooke Shields's character shipwrecked?
# 10368 In what state is the nation's highest ZIP code, 99950, located?
# 10397 In what country were 6,000 life-size clay soldiers called the "terracotta army" found?
# 10432 In which of these cities would you find the Empire State Building?
# 10450 For what successful pop group was Peter Gabriel once the lead singer?
# 10452 In what state was the transcontinental railroad completed in 1869?
# 10497 In a formal place setting, where should a wine glass be positioned relative to the plate?
# 10579 During what war were soldiers on one side given the nickname "Johnny Reb"?
# 10617 On what part of the body would an injured person normally wear a cervical collar?
# 10636 At what fictional hospital does the TV series "ER" take place?
# 10637 In what world capital would you find the Forbidden City?
# 10646 In what U.S. national park would you find the large mass of granite called El Capitan?
# 10651 In which of these sports does the game begin when a referee drops an object onto the playing surface?
# 10698 In which of these animals would you find a swim bladder?
# 10783 How do chickens incubate their eggs?
# 11001 On what 1970s game show did the "performer" Gene, Gene the Dancing Machine first appear?
# 11022 On the children's TV series "The Banana Splits Adventure Hour," how does the chorus to the theme song begin?
# 17224 In what creature would you most likely find a wishbone?
# 17229 In which of the following countries is a "sari" part of the traditional dress?
# 17264 Assuming it's autobiographical, whose song "Summer of '69" had him playing guitar in a band and courting a girl at the tender age of 9?
# 17275 On which of the following would you most likely find the abbreviation "kWh"?
# 17283 In what American city is the internationally famous business district known as Wall Street located?
# 17284 With what musical instrument is Elton John most closely associated?
# 17316 In which of the following appliances would you find a device called an agitator?
# 17341 On what part of a bird can its crest be found?
# 17524 Where can the world's largest supply of fresh water be found?
# 17570 On what kind of vehicle would you most likely find a "banana seat"?
# 17594 In what city did the infamous 1991 “Tailhook” convention take place?
# 17598 On what part of the golf course does a golfer traditionally putt?
# 17642 Where is the Rock and Roll Hall of Fame and Museum?
# 17772 If you were caught "tippling" in public, by definition, what are you most likely to be arrested for?
# 17779 In the abbreviation for which of the following government associations does the "F" not stand for "federal"?
# 17786 In what building do people sit in pews?
# 17787 Where is the rattle on a rattlesnake’s body?
# 17925 On which grounds would you find the official residence of the vice president of the United States?
# 17956 In which of these films does Marilyn Monroe's character die?
# 18036 In which of the following places would you most likely find a pothole?
# 18051 In what part of the house would you normally find a banister?
# 18120 According to Chistopher Marlowe’s play, for what does Dr. Faustus sell his soul?
# 18124 How are the medals at Olympic events traditionally awarded?
# 18130 For which of the following occasions is the U.S. flag customarily flown at half-staff?
# 18141 How often does the Earth complete one full rotation on its axis?
# 18156 Where are the British crown jewels kept?
# 18221 In the 2000 movie "Shaft," how is Samuel L. Jackson's character related to the 1970s Shaft?
# 18260 Since 2014, whose sonorous voice has been heard in Arby's ads insisting "We have the meats"?
# 18292 Because he's a vegetarian, who once refused Weird Al’s request to record a parody of “Live and Let Die” titled “Chicken Pot Pie”?
# 18365 With which of the following musical genres was singer Kurt Cobain most associated?
# 18370 On what television show did Ross Perot first announce that he was running for president in 1992?
# 18380 In what month is Boxing Day celebrated in England?
# 18388 In what mountain range would you find Mount Everest?
# 18444 Where on a woman's dress would you most likely find the hemline?
# 18467 In which of the following Central American countries would you find the Mosquito Coast?
# 18508 In what time zone would you find New York City?
# 18511 In what position does the winged mammal known as a bat normally rest?
# 18531 Where is Queen Maud Land located?
# 18615 On which of the following vehicles would you normally find a kickstand?
# 18619 In the TV series "The Fresh Prince of Bel-Air," where is the title character originally from?
# 18627 According to the United Nations, in what year was the world's population half of its present total?
# 18639 In what war did the American colonies win their independence from Great Britain?
# 18659 For which film did Tim Burton spend 5 months training 40 squirrels to crack nuts?
# 18698 Don't tell Comcast, but according to Variety and a December 2015 Pew study, 16% of adults between the ages of 18 and 29 have never had what?
# 18727 According to mythology, whose hair was turned into snakes by the goddess Athena?
# 18729 On what date is Abraham Lincoln's actual birthday?
# 18769 To which island was Napoleon Bonaparte exiled in 1814?
# 18807 On what continent would you find the Nubian Desert?
# 19028 When doing the bunny hop, where should you place your hands if there is a person in front of you?
# 19041 On a typical house, where are the eaves located?
# 19076 In which of these places would a bat most likely live?
# 19147 Where are you most likely to hold a clambake?
# 19223 In what world city would you find the famous Trafalgar Square?
# 19224 In what field is Moby a popular artist?
# 19225 In what U.S. state would you find the original site of Boys Town?
# 19237 In the TV series "Ed," where does the title character open a law office?
# 19271 In which of the following countries did reggae music originate?
# 19332 In what sport did the phrase "hitting the wall" originate to describe its exhausted athletes?
# 19364 Where was David Koresh’s Branch Davidian compound located?
# 19368 According to the Declaration of Independence, how are all men created?
# 19402 In which of the following sporting events does the checkered flag proclaim the winner?
# 19405 Where was room 222 located in the 1970s television series "Room 222"?
# 19435 At which of the following 2007 "Reunion Tour" stops did the Police perform in a U.S. state capital?
# 19469 On which classic sitcom were the actors who played the main family's "mom" and "dad" born on the exact same day: June 21, 1947?
# 19483 From what direction does the sun appear to rise?
# 19562 In which of these kitchen appliances would you "nuke" leftover food?
# 19585 On what part of Arnold Schwarzenegger's body would you find his huge pectoral muscles?
# 19759 Where do "candy stripers" volunteer?
# 19775 In what sport do competitors traditionally wear a jacket and cap referred to as "silks"?
# 19819 Where does a wolf give birth to her young?
# 19820 At what event would you most likely hear a commencement address?
# 19876 In what animal's shell will you most likely find a pearl?
# 19877 How is the number 2000 expressed in Roman numerals?
# 19887 To which of the following places would you go to learn about celestial objects?
# 19929 On which of these websites will you find the articles "6 Workout Tips You Need to Know For Ramadan" and "5 Products to Get You Skin Eid Ready"?
# 19944 According to the title of his 1990 book, where did author Peter Mayle spend a year?
# 19955 Over which South American city does the 100-foot statue "Christ the Redeemer" stand?
# 19956 In the 1997 film "Good Will Hunting", at what college does Matt Damon's character work?
# 20056 Where does the weather phenomenon known as El Niño originate?
# 20101 Where are the smallest bones in the human body?
# 20146 In what country are all U.S. Major League baseballs currently manufactured?
# 20160 In which of these countries is bowing a customary greeting?
# 20162 In what month is Martin Luther King Jr.'s birthday celebrated?
# 20171 By what famous nickname is the Loch Ness monster known?
# 20178 Facing the presiding officer in the U.S. Senate chamber, where do most Republican senators sit?
# 20179 Under what mountain is the operation center for the nuclear missile tracking station NORAD buried?
# 20189 On what sort of surface do Olympic bobsledders compete?
# 20197 After the U.S. Constitution was ratified, where was the first federal capital?
# 20199 Where does natural maple syrup come from?
# 20211 Where was the first foreign visit made by a sitting U.S. president?
# 20214 Where does a camel store the majority of the fat it uses to sustain itself on long desert journeys?
# 20217 On what does a lever balance?
# 20230 By definition, where does an abyssopelagic animal live?
# 20240 In the Bible, how long did the Israelites wander the desert before entering the Promised Land?
# 20243 In what state was Abraham Lincoln born?
# 20252 If winning all four major entertainment awards is a show business "grand slam", whose bases are loaded, with only one award missing?
# 20258 While now you might bring wine or a gift basket, for what type of appropriately-named party is it said to have once been traditional to bring firewood?
# 20272 When cooking, how does a person truss a turkey?
# 20356 Try to say "pad kid poured curd pulled cod" ten times fast, and you'll know exactly why MIT researchers named it the world's toughest what?
# 20401 In which of the following movies does a character say the line "I see dead people"?
# 20458 In a song from the 1957 musical "The Music Man," where do "ya got trouble"?
# 20461 In the 1993 book "The Celestine Prophecy: An Adventure," where does the narrator go in search of an ancient text?
# 21807 During what kind of dance does a person known as a "caller" direct the movements of the dancers?
# 21817 After he explored it with William Clark, who was named governor of the Louisiana Territory in 1807?
# 21846 On what space shuttle did John Glenn travel when he returned to space in 1998?
# 21857 By what name has television host Don Herbert been known since 1951?
# 21890 Though now associated with Barack Obama, who used the actual word "change" more than any other president in his inaugural address?
# 21907 At the start of the lullaby "Rock-A-Bye-Baby," where is the baby?
# 21912 Where would you find a transom window?
# 21920 If you're driving in a gridded city, headed due west, and you take a left, and then another left, in which direction are you headed?
# 21968 In 2008, why did "Harry Potter" star Daniel Radcliffe make headlines for his Broadway debut in the play "Equus"?
# 22007 In what language was the "Common Manifesto" originally written?
# 22043 Where would you most likely use a Boogie Board?
# 22086 According to the Washington Irving tale, how long did Rip Van Winkle sleep?
# 22089 Before selling it to the U.S., from what country did France receive Louisiana?
# 22098 In what Olympic throwing event are you forbidden from spinning around during the curse of a throw?
# 22113 In a classic "SNL" sketch, how do the Czechoslovakian "guys" portrayed by Steve Martin and Dan Aykroyd describe themselves?
# 22199 In Orson Welles’s radio dramatization of “War of the Worlds,” where do the Martians land?
# 22271 In the story of "Little Red Riding Hood," where does she go with her basket of food?
# 22287 In what ocean would you find the Sargasso Sea?
# 22295 In what part of the human body would you find rods and cones?
# 22296 Where does the German accent mark, the "umlaut," appear in the brand name Haagen-Dazs?
# 22340 Opening in June 2000, where can you find a museum inspired by Jimi Hendrix?
# 22423 In which U.S. city would a letter arrive if it was mailed to the zip code "90210"?
# 22425 If you are standing in "Motown", where are you?
# 22457 In what 2013 film does Lake Bell pursue a job in the male-dominated world of movie trailer voice-overs?
# 22510 On what vehicle would a spinnaker most likely be found?
# 22513 Where is the Byzantine cathedral known as the Hagia Sophia located?
# 22527 In which of the following places are you routinely asked whether you packed your own bag?
# 22562 In which of these pro sports does an umpire sit in a high chair alongside the playing surface?
# 22629 As the common saying goes "Always a bridesmaid never a what"?
# 22676 Where is the Hubble Telescope located?
# 22707 In what city would you find the university known as "The Sorbonne"?
# 22727 In the 2000 movie "Space Cowboys," why must Clint Eastwood's character go into space?
# 22737 In which of these card games do you say the name of the game when you win a hand?
# 22838 On what article of clothing would you find a French cuff?
# 22934 On what short-lived 2014 reality show did 12 unsuspecting women chase after a redheaded actor impersonating “Britain’s most eligible bachelor”?
# 22956 In what branch of the U.S. armed forces did singer Elvis Presley serve?
# 23004 If you cannot get your hair to look good no matter what you try, if is said "you are having a" what?
# 23020 In what capital city would you find the ancient landmark, the Temple of Athena Nike?
# 23027 If you are being blown around in "The Windy City," where are you?
# 23054 Despite its name, for which of the following would you NOT see a cardiologist?
# 23080 Where in a house is a sump pump usually found?
# 23197 In which of these movies does Leonardo DiCaprio portray a fictional character and not a real-life person?
# 23203 In which of the following fairy tales would you find a goose that lays golden eggs?
# 23280 If a man jokingly introduces you to his "missus," to whom is he introducing you?
# 23360 With what famous phrase was host Johnny Carson regularly introduced on "The Tonight Show"?
# 23361 Where on the body would you find what are known as "love handles"?
# 23363 How do you fasten a pair of Levi's 501 jeans?
# 23364 During a theatre performance, where do the orchestra musicians traditionally sit?
# 23376 In which professional sport are players sent to the penalty box after breaking the rules?
# 23377 In a current Budweiser advertising campaign, how do friends greet each other?
# 23383 In 1543, whose radical theory of a sun-centered universe was first published?
# 23428 If a lightning bolt travels at 100,000 meters per second, about how much faster is the lightning bolt than 100-meter sprinter Usain Bolt's record time?
# 23443 In a common phrase about impending disaster, whose sword is said to be hanging over your head?
# 23514 In the song "Over the River and Through the Woods," where are the people going?
# 23522 In what town can you visit the International UFO Museum and Research Center?
# 23532 For what purpose were the Egyptian pyramids believed to have been built?
# 23536 In what country is the musical "Fiddler on the Roof" set?
# 23586 On what part of the body would a person most likely wear a toupée?
# 23644 In what literary classic are there horselike creatures called Houyhnhnms?
# 23649 In the lyrics of the song, on what type of horse did “Yankee Doodle” ride to town?
# 23656 In which of the following U.S. states would you find the mountain resort of Jackson Hole?
# 23692 Though silence is not an official rule, at which of these sporting events are spectators traditionally expected to remain quiet?
# 23705 On what part of the body would you traditionally wear an epaulet?
# 23712 Before the American colonies switched to the Gregorian calendar, on what date did their new year start?
# 23713 On what part of the body would a person most likely wear a moccasin?
# 23734 In the popular song by Jan and Dean, where is the "little old lady" from?
# 23738 During what war was the TV drama "China Beach" set?
# 23740 Where was the signing of the treaty that ended the American Revolution?
# 23749 Born in 1977, in what year will Liv Tyler be as old as her first name in Roman numerals?
# 23755 During what season do the cherry blossoms bloom in Washington, DC?
# 23763 In Winston Churchill's quote, "Never...was so much owed by so many to so few," who are the "few"?
# 23791 On a sailing ship, where would a lookout most likely be stationed?
# 23887 In which of these places is an "S" located on Superman's costume?
# 23912 On what part of a car would you normally find hubcaps?
# 23945 Where is a person's hyoglossus muscle?
# 24010 On which of these islands would you find signs that instruct visitors not to touch the moai?
# 24043 For which of the following track and field events is it required to jump over something?
# 24108 Where is the Kuiper Belt?
# 24133 In which of these movies does a character played by Samuel L. Jackson not meet a violent and untimely demise?
# 24140 In which of the following European countries would you find the Matterhorn?
# 24146 In the Supreme Court case Brown v. Board of Education, in what city was the board located?
# 24245 After John F. Kennedy's assassination, where was Lyndon Johnson sworn in as U.S. president?
# 24276 In what state was former president Jimmy Carter born and raised?
# 24283 On November 22, 1963, where was Lee Harvey Oswald arrested?
# 24298 At approximately what speed did Chuck Yeager break the sound barrier in 1947?
# 24321 In which of these movies does Eddie Murphy play just one character?
# 24444 Where do female marsupials normally carry their young after birth?
# 24446 Where is the so-called "Borscht Belt" located?
# 24634 In which of the following sports is the object to attain the lowest score?
# 24658 Why do people bring their collectibles to the PBS series "Antiques Roadshow"?
# 24759 During which of these celestial events are the Sun, Moon and Earth aligned in a straight line, a condition astronomers call "Syzygy"?
# 24762 Where are the parietal bones located on the human skeleton?

# %% [markdown]
# # Main VP

# %%
auxes = {'is', 'are', 'am', 'was', 'were', 'do', 'did', 'has', 'have', 'had', 'do', 'does', 'did', 'will', 'would', 'can', 'could', 'shall', 'should', 'may', 'might', 'must'}

def get_main_VP(tree):
    '''
    The main VP node has the following properties:
    1. No other VP is higher than it,
    2. All S nodes that dominate it dominate all maximal VPs,
    '''
    # 1. Get he highest VPs
    max_VPs = get_maximal(tree, 'VP')
    # Exception: Sometimes we get an inverted aux classed as a VP
    max_VPs = [max_VP for max_VP in max_VPs if not (set(tree[max_VP].leaves()).issubset(auxes))]

    if not max_VPs:
        # Exception: Sometimes we get an SQ directly dominating the main V
        max_SQ = get_maximal(tree, 'SQ', exact='exact')
        if len(max_SQ) == 1:
            daughters = get_daughters(tree, max_SQ[0])
            if any(tree[daughter].label().startswith('VB') for daughter in daughters):
                max_VPs = max_SQ
    # Escape early if failed to find any VPs
    if not max_VPs:
        return None

    min_length = min([len(max_VP) for max_VP in max_VPs])
    main_VPs = [max_VP for max_VP in max_VPs if len(max_VP)==min_length]
    if len(main_VPs) > 1:
        return None
    main_VP = main_VPs[0]

    # Check if mother contains an NP to the left. If it *doesn't*, then take that node instead.
    left_siblings = [sibling for sibling in get_siblings(tree,main_VP) if sibling[-1]<main_VP[-1]]
    if not any(tree[sibling].label().endswith('NP') for sibling in left_siblings):
        main_VP = get_mother(tree, main_VP)

    # Check if mother is unary-branching. If so, then take that node instead
    mother = get_mother(tree, main_VP)
    daughters = get_daughters(tree, mother)
    while len(daughters) == 1:
        main_VP = tuple(mother)
        mother = get_mother(tree, main_VP)
        daughters = get_daughters(tree, mother)

    return main_VP

# %%
# Illustrating 'get_main_VP'
tree = trees[36]
tree.pretty_print()
main_VP = get_main_VP(tree)
tree[main_VP].pretty_print()
# Out:
#                                                             SBARQ
#        _______________________________________________________|______________________________________________
#       |                           S                                                                          |
#       |                 __________|_____________                                                             |
#       |                |                        VP                                                           |
#       |                |           _____________|___________________                                         |
#       |                |          |                                 NP                                       |
#       |                |          |              ___________________|_____________                           |
#       |                |          |             |                                 VP                         |
#       |                |          |             |                    _____________|____                      |
#       |                |          |             |                   |                  S                     |
#       |                |          |             |                   |                  |                     |
#       |                |          |             |                   |                  NP                    |
#       |                |          |             |                   |          ________|___                  |
#       |                |          |             |                   |         |            PP                |
#       |                |          |             |                   |         |         ___|___              |
#      WHNP             ADVP        |             NP                  |         NP       |       NP            |
#   ____|_____           |          |       ______|_____________      |      ___|___     |    ___|______       |
#  WP         NN         RB        VBZ     DT     JJ      JJ    NN   VBN    DT     NNP   IN  DT        NNP     .
#  |          |          |          |      |      |       |     |     |     |       |    |   |          |      |
# What      leader traditionally receives  a  ceremonial gold  ring called the     Ring  of the     Fisherman  ?
#
#                  S
#        __________|_____________
#       |                        VP
#       |           _____________|__________________
#       |          |                                NP
#       |          |              __________________|_____________
#       |          |             |                                VP
#       |          |             |                   _____________|____
#       |          |             |                  |                  S
#       |          |             |                  |                  |
#       |          |             |                  |                  NP
#       |          |             |                  |          ________|___
#       |          |             |                  |         |            PP
#       |          |             |                  |         |         ___|___
#      ADVP        |             NP                 |         NP       |       NP
#       |          |       ______|____________      |      ___|___     |    ___|______
#       RB        VBZ     DT     JJ      JJ   NN   VBN    DT     NNP   IN  DT        NNP
#       |          |      |      |       |    |     |     |       |    |   |          |
# traditionally receives  a  ceremonial gold ring called the     Ring  of the     Fisherman

# %%
# This is not working -- I'm not sure why
'''
# Check bail rate
fails = [i for i,tree in enumerate(trees) if get_main_VP(tree) is None]
passes = [j for j in range(len(trees)) if j not in fails]
print('Passes:', len(passes))
print('Fails:', len(fails))
print('Total:', len(trees))
'''
# Out:
# "\n# Check bail rate\nfails = [i for i,tree in enumerate(trees) if get_main_VP(tree) is None]\npasses = [j for j in range(len(trees)) if j not in fails]\nprint('Passes:', len(passes))\nprint('Fails:', len(fails))\nprint('Total:', len(trees))\n"

# %%
'''
# If we want, we can look at the failures
for i in fails:
    print(i, parsed_questions['Question'][i])

trees[961].pretty_print()
'''
# Out:
# "\n# If we want, we can look at the failures\nfor i in fails:\n    print(i, parsed_questions['Question'][i])\n\ntrees[961].pretty_print()\n"

# %% [markdown]
# # Collecting labels

# %%
from tqdm import tqdm

labels = []
for tree in tqdm(trees):
    main_S = get_main_S(tree)
    if main_S is None: # Bail
        labels.append('manual')
    else:
        siblings = get_siblings(tree, main_S)
        if siblings is None: # Bail
            labels.append('manual')
        elif any(tree[sibling].label().startswith('WH') for sibling in siblings):
            # This will happen if we have a fronted wh-adverbial
            labels.append('ex-situ')
        else:
            daughters = get_daughters(tree, main_S)
            if daughters is None: # Bail
                labels.append('manual')
            elif any(tree[daughter].label() == 'WHNP' for daughter in daughters):
                main_VP = get_main_VP(tree)
                if main_VP is None: # Bail
                    labels.append('manual')
                elif main_VP in daughters:
                    labels.append('wh-subject')
                else:
                    labels.append('ex-situ')
            else:
                labels.append('in-situ')
# Out:
# 100%|██████████| 24795/24795 [01:27<00:00, 281.98it/s]

# %%
parsed_questions['Label'] = labels
parsed_questions[['Contestant', 'Question', 'Label']].to_csv('labeled_questions.csv', index=False)
parsed_questions
# Out:
#          Contestant                                           Question  \
# 0        Aaron Gold  According to Good Housekeeping, most homeowner...
# 1        Aaron Gold  "There is a Sucker Born Ev'ry Minute" and "Joi...
# 2        Aaron Gold  Until it adopted the euro in 2002, fittingly, ...
# 3        Aaron Gold  Which of these is the correct spelling of what...
# 4       Aaron Hauck  In 2006, the WHO reported that thousands of pe...
# ...             ...                                                ...
# 24790  Zeke Spector  As Crayola's website explains, "while artists ...
# 24791  Zeke Spector  Born Amethyst Amelia Kelly, what recording art...
# 24792  Zeke Spector  Which one of these things is NOT true of the p...
# 24793  Zeke Spector  Since in 1992 it was ruled that anyone in the ...
# 24794  Zeke Spector  In photographs, Harriet Tubman is often seen w...
#
#                                                    Parse       Label
# 0      (S (PP (VBG According) (PP (IN to) (NP (NNP Go...     in-situ
# 1      (S (NP (`` ") (S (NP (EX There)) (VP (VBZ is) ...     in-situ
# 2      (SBARQ (SBAR (IN Until) (S (NP (PRP it)) (VP (...  wh-subject
# 3      (SBARQ (WHNP (WHNP (WDT Which)) (PP (IN of) (N...  wh-subject
# 4      (S (PP (IN In) (NP (CD 2006))) (, ,) (NP (DT t...     in-situ
# ...                                                  ...         ...
# 24790  (S (SBAR (IN As) (S (NP (NP (NNP Crayola) (POS...     in-situ
# 24791  (SBARQ (S (VP (VBN Born) (NP (NNP Amethyst) (N...  wh-subject
# 24792  (SBARQ (WHNP (NP (WDT Which) (CD one)) (PP (IN...      manual
# 24793  (S (SBAR (IN Since) (S (PP (IN in) (NP (CD 199...     in-situ
# 24794  (S (PP (IN In) (NP (NNS photographs))) (, ,) (...     in-situ
#
# [24795 rows x 4 columns]
# Warning: total number of rows (24795) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
# Counts
print('# in-situ questions:', len(parsed_questions[parsed_questions['Label']=='in-situ']))
print('# ex-situ questions:', len(parsed_questions[parsed_questions['Label']=='ex-situ']))
print('# wh-subject questions:', len(parsed_questions[parsed_questions['Label']=='wh-subject']))
print('Total non-manual questions', len(parsed_questions[parsed_questions['Label']!='manual']))
print('Total questions', len(parsed_questions['Label']))
# Out:
# # in-situ questions: 12873
# # ex-situ questions: 1880
# # wh-subject questions: 9629
# Total non-manual questions 24382
# Total questions 24795

# %% [markdown]
# # Main Subj (Abandoned)

# %%
# I thought we might need to identify the main subject this way, but I went down a wrong path with this.

def get_main_subj(tree):
    '''
    The main subject should have these properties:
    1. It is a daughter of the main S node
    2. It is the closest such node to the main verb either on the left (first preference) or on the right
    '''

    # 1. Get NP daughters of main S
    main_S = get_main_S(tree)
    # If we fail to find a maximal S node, then we've failed. Return None.
    if main_S is None:
        return None
    daughters = get_daughters(tree, main_S)
    main_NPs = [daughter for daughter in daughters if tree[daughter].label().endswith('NP')]
    if len(main_NPs) == 0:
        return None
    if len(main_NPs) == 1:
        return main_NPs[0]

    # 2. Narrow down to the closest NP to the left of the main VP
    main_VP = get_main_VP(tree)
    if main_VP is None:
        return None
    # Get the main verb
    main_VBs = [VB for VB in get_daughters(tree, main_VP) if tree[VB].label().startswith('VB') or tree[VB].label().startswith('MD')]
    if not main_VBs:
        return None
    # If there are multiple, we want the leftmost within the VP
    main_VB = min(main_VBs, key=lambda x:x[-1]) # The key here gets the leftmost element
    # We need the position of the main VB
    VB_height = len(main_VB)-1
    NP_height = len(main_NPs[0])-1
    if VB_height > NP_height: # If the VB is lower than the NPs
        VB_idx = main_VB[NP_height]
        candidates = [NP for NP in main_NPs if NP[-1]<VB_idx]
        # Catch exceptions:
        if not candidates:
            return None
        # In this case, we expect NPs to the be on the left. Then we want the one with the least negative difference
        main_NP = max(candidates, key=lambda x: x[len(x)-1] - VB_idx) # If
    else: # If the VB is not lower than the NPs (they should be same height in this case)
        VB_idx = main_VB[-1]
        candidates = [NP for NP in main_NPs if NP[VB_height]>VB_idx]
        if not candidates:
            return None
        # In this case, we expect NPs to the be on the right. Then we want the one with the least negative difference
        main_NP = max(candidates, key=lambda x: VB_idx - x[len(x)-1])

    return main_NP

# %%
# Testing
tree = trees[63]
tree.pretty_print()
print('main_S')
main_S = get_main_S(tree)
tree[main_S].pretty_print()

print('main_VP')
main_VP = get_main_VP(tree)
tree[main_VP].pretty_print()

print('main_NP')
main_subj = get_main_subj(tree)
tree[main_subj].pretty_print()
# Out:
#                                                     SBARQ
#            ___________________________________________|___________________________________________________________
#           |                                 |   |           SQ                                                    |
#           |                                 |   |      _____|_______________                                      |
#           |                                 |   |     |     |               VP                                    |
#           |                                 |   |     |     |         ______|___________                          |
#          SPP                                |   |     |     |        |                  S                         |
#    _______|____________                     |   |     |     |        |       ___________|___                      |
#   |                    S                    |   |     |     |        |      |               VP                    |
#   |        ____________|______              |   |     |     |        |      |      _________|___                  |
#   |       |                   VP            |   |     |     |        |      |     |             PP                |
#   |       |       ____________|___          |   |     |     |        |      |     |      _______|___              |
#   |       NP     |    ADVP        NP        |  WHNP   |     NP       |      |     |     |           NP            |
#   |       |      |     |       ___|____     |   |     |     |        |      |     |     |    _______|______       |
#   IN      NN    VBZ    RB     DT  JJ   NN   ,   WP   VBZ   NNP       VB     RB   VBG    IN  DT      NN     NN     .
#   |       |      |     |      |   |    |    |   |     |     |        |      |     |     |   |       |      |      |
# While deodorant  is probably  a  good idea  ,  what  does Forbes recommend NOT wearing  to  a      job interview  ?
#
# main_S
#                                                     SBARQ
#            ___________________________________________|___________________________________________________________
#           |                                 |   |           SQ                                                    |
#           |                                 |   |      _____|_______________                                      |
#           |                                 |   |     |     |               VP                                    |
#           |                                 |   |     |     |         ______|___________                          |
#          SPP                                |   |     |     |        |                  S                         |
#    _______|____________                     |   |     |     |        |       ___________|___                      |
#   |                    S                    |   |     |     |        |      |               VP                    |
#   |        ____________|______              |   |     |     |        |      |      _________|___                  |
#   |       |                   VP            |   |     |     |        |      |     |             PP                |
#   |       |       ____________|___          |   |     |     |        |      |     |      _______|___              |
#   |       NP     |    ADVP        NP        |  WHNP   |     NP       |      |     |     |           NP            |
#   |       |      |     |       ___|____     |   |     |     |        |      |     |     |    _______|______       |
#   IN      NN    VBZ    RB     DT  JJ   NN   ,   WP   VBZ   NNP       VB     RB   VBG    IN  DT      NN     NN     .
#   |       |      |     |      |   |    |    |   |     |     |        |      |     |     |   |       |      |      |
# While deodorant  is probably  a  good idea  ,  what  does Forbes recommend NOT wearing  to  a      job interview  ?
#
# main_VP
#            VP
#      ______|___________
#     |                  S
#     |       ___________|___
#     |      |               VP
#     |      |      _________|___
#     |      |     |             PP
#     |      |     |      _______|___
#     |      |     |     |           NP
#     |      |     |     |    _______|______
#     VB     RB   VBG    IN  DT      NN     NN
#     |      |     |     |   |       |      |
# recommend NOT wearing  to  a      job interview
#
# main_NP
# WHNP
#  |
#  WP
#  |
# what

# %%
# Check exceptions
fails = [i for i,tree in enumerate(trees) if get_main_subj(tree) is None]
passes = [j for j in range(len(trees)) if j not in fails]
print('Passes:', len(passes))
print('Fails:', len(fails))
print('Total:', len(trees))
# Out:
# Passes: 24029
# Fails: 766
# Total: 24795
